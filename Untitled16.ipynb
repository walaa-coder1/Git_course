# %% [markdown]
# <a href="https://colab.research.google.com/github/walaa-coder1/Git_course/blob/main/Untitled16.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Problem 1

num1 = 3
num2 = 4
num3 = 5

print("1a:", num1 + num2)                # 3 + 4 = 7
print("1b:", num3 - num1)                # 5 - 3 = 2
print("1c:", num1 * (num2 + num3))       # 3 * (4 + 5) = 27
print("1d:", num1 * num2 + num3)         # (3 * 4) + 5 = 17
print("1e:", num3 / num1)                # 5 / 3 = 1.666...
print("1f:", num3 // num1)               # 5 // 3 = 1 (floor division)
print("1g:", num3 % num1)                # 5 % 3 = 2

num1 = float(num1)
num2 = float(num2)
num3 = float(num3)

print("\nFloat results:")
print("1a:", num1 + num2)
print("1b:", num3 - num1)
print("1c:", num1 * (num2 + num3))
print("1d:", num1 * num2 + num3)
print("1e:", num3 / num1)
print("1f:", num3 // num1)
print("1g:", num3 % num1)
# Out:
# 1a: 7
# 1b: 2
# 1c: 27
# 1d: 17
# 1e: 1.6666666666666667
# 1f: 1
# 1g: 2
#
# Float results:
# 1a: 7.0
# 1b: 2.0
# 1c: 27.0
# 1d: 17.0
# 1e: 1.6666666666666667
# 1f: 1.0
# 1g: 2.0

# %%
# Problem 2
x, y, z, g = 1, 2, 3, 4
print("\n2a:", x + y / z * g)   # 1 + (2/3)*4
print("2b:", y ** z)            # 2 ** 3 = 8
# Out:
# 2a: 3.6666666666666665
# 2b: 8

# %%
# Problem 3
# ------------------------------------
str_a = "Python"
str_b = " is a "
str_c = "times fun language"
num = 1000

# Concatenation
str_ab = str_a + str_b + str(num) + " " + str_c
print("\n3a:", str_ab)

# Repeat str_a 10 times
str_a10 = str_a * 10
print("3b:", str_a10)
# Out:
# 3a: Python is a 1000 times fun language
# 3b: PythonPythonPythonPythonPythonPythonPythonPythonPythonPython

# %%
# Problem 4

num1 = -5
num2 = 3.2
num3 = 5.7
num4 = 625

# Absolute value
print("\n4a:", abs(num1))

# Round to nearest integer
print("4b num2:", round(num2))
print("4b num3:", round(num3))

# Square root
import math
print("4c:", math.sqrt(num4))
# Out:
# 4a: 5
# 4b num2: 3
# 4b num3: 6
# 4c: 25.0

# %%
# Problem 5
# ------------------------------------
# Basic multiplication calculator
print("\nProblem 5: Multiplication Calculator")
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
print("Result:", a * b)
# Out:
# Problem 5: Multiplication Calculator
# Enter first number: 5
# Enter second number: 5
# Result: 25.0

# %%
# 1. Odd or Even
num = int(input("Enter a number: "))
if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number: 5
# Odd

# %%
# 2. Pass or Fail
score = int(input("Enter student score (0-100): "))
if score >= 50:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter student score (0-100): 60
# Pass

# %%
# 3. Largest of 3 numbers
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
print("Largest number is:", max(a, b, c))
# Out:
# Enter first number: 2
# Enter second number: 10
# Enter third number: 5
# Largest number is: 10

# %%
 #4. Counting with for
for i in range(1, 11):
    print(i)

# %%
# 5. Grade Calculator
score = int(input("Enter score (0-100): "))
if 90 <= score <= 100:
    print("Grade: A")
elif 80 <= score <= 89:
    print("Grade: B")
elif 70 <= score <= 79:
    print("Grade: C")
elif 60 <= score <= 69:
    print("Grade: D")
else:
    print("Grade: F")
# Out:
# Enter score (0-100): 80
# Grade: B

# %%
# 6. Multiplication Table
num = int(input("Enter a number for multiplication table: "))
for i in range(1, 11):
    print(f"{num} x {i} = {num * i}")
# Out:
# Enter a number for multiplication table: 5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
# 7. Sum of Even Numbers
total = 0
for i in range(1, 51):
    if i % 2 == 0:
        total += i
print("Sum of even numbers from 1 to 50 is:", total)
# Out:
# Sum of even numbers from 1 to 50 is: 650

# %%
# 8. Factorial with while
num = int(input("Enter a number for factorial: "))
factorial = 1
i = 1
while i <= num:
    factorial *= i
    i += 1
print(f"Factorial of {num} is: {factorial}")
# Out:
# Enter a number for factorial: 10
# Factorial of 10 is: 3628800
